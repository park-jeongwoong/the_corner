        browser.find_element(by=By.XPATH, value = elementXpath).click()

        # Find the elements for each PER value
        element_xpath_list = ['/html/body/div/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[27]/td[1]',
                              '/html/body/div/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[27]/td[2]',
                              '/html/body/div/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[27]/td[3]',
                              '/html/body/div/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[27]/td[4]',
                              '/html/body/div/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[27]/td[5]']

        result = 0  # Initialize result to 0

        # Loop through each element and check if it meets the condition
        for element_xpath in element_xpath_list:
            element = browser.find_element(by=By.XPATH, value=element_xpath)
            per_value = element.text
            
            
            # PER가 음수인 경우가 있는데(N/I가 음수) 네이버 증권은 그걸 N/A로 표시해. 그걸 제거하는 부분.
            try:
                # Attempt to convert per_value to float
                per_value_float = float(per_value)
                # If conversion is successful, update per_value with the float value
                per_value = per_value_float
            except ValueError:
                # If conversion fails, per_value is not a valid real number, leave it unchanged
                continue
                
                
            # 조건에 맞는 지 확인
            if not(8 <= per_value <= 20): # 10에서 15보다 조금 더 넓게 잡았어. 원하면 바꾸면 돼!
                    continue
            result += 1 # PER가 8과 20 사이라면 더하기 1해주는 구조. 
            
        # 맞으면 저장 5개년 중 2개 이상이면 저장하도록 설정했어. 원하면 바꾸면 돼!
        if result >= 0:
            element_xpath = '/html/body/div[1]/form/div[1]/div/div[2]/div[1]/div/table/tbody/tr[1]/td/dl/dt[1]/span'
            candidate = browser.find_element(by=By.XPATH, value=element_xpath).text
        
            # 매출액 구하기
            sales = []
            element_xpath_list = ['/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[1]/td[1]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[1]/td[2]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[1]/td[3]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[1]/td[4]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[1]/td[5]']
            for element_xpath in element_xpath_list:
                element = browser.find_element(by=By.XPATH, value=element_xpath).text
                sales.append(element)

            # 영업이익 구하기
            profit = []
            element_xpath_list = ['/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[2]/td[1]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[2]/td[2]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[2]/td[3]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[2]/td[4]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[2]/td[5]']
            for element_xpath in element_xpath_list:
                element = browser.find_element(by=By.XPATH, value=element_xpath).text
                profit.append(element)

            # 당기순이익 구하기
            ni = []
            element_xpath_list = ['/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[5]/td[1]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[5]/td[2]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[5]/td[3]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[5]/td[4]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[5]/td[5]']
            for element_xpath in element_xpath_list:
                element = browser.find_element(by=By.XPATH, value=element_xpath).text
                ni.append(element)

            # 영업활동 현금흐름 구하기
            cashflow = []
            element_xpath_list = ['/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[14]/td[1]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[14]/td[2]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[14]/td[3]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[14]/td[4]',
                                  '/html/body/div[1]/form/div[1]/div/div[2]/div[3]/div/div/div[14]/table[2]/tbody/tr[14]/td[5]']
            for element_xpath in element_xpath_list:
                element = browser.find_element(by=By.XPATH, value=element_xpath).text
                cashflow.append(element)

            dcf_candidate.append([candidate,sales,profit,ni,cashflow])
        
            
    finally:
        browser.quit()
        
        
# 데이터 저장

import pandas as pd

# Create an empty DataFrame with column names
columns = ['Company Name', 'Sales', 'Operating Income', 'Net Income', 'Cash Flow from Operating Activities']
df = pd.DataFrame(columns=columns)

# Iterate through each element in dcf_candidate and append data to DataFrame
for item in dcf_candidate:
    company_name = item[0]
    sales = item[1]
    operating_income = item[2]
    net_income = item[3]
    cash_flow = item[4]
    data = {'Company Name': [company_name,'','','',''],
            'Sales': sales,
            'Operating Income': operating_income,
            'Net Income': net_income,
            'Cash Flow from Operating Activities': cash_flow}
    df = df.append(pd.DataFrame(data))

# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Write the DataFrame to an Excel file
df.to_excel('organized_data.xlsx', index=False)
# Out:
# C:\Users\dck\AppData\Local\Temp/ipykernel_10148/669013292.py:17: DeprecationWarning: use options instead of chrome_options
#   browser = webdriver.Chrome(chrome_options=options)
